# %% [markdown]
# Importing the necessary packages

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %% [markdown]
# Import DB connection details from external file (not synced to repository) to avoid sharing connection details. Alternatively define a variable for the connection details for the database directly here.

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the connection string from environment variables
conn_string = os.getenv("POSTGRESQL_URL")
# conn_string='postgresql://user@host:port/db-name'

# %% [markdown]
# Establishing the database connection

# %%
 
db = create_engine(conn_string) 
conn = db.connect()

# %% [markdown]
# Load csv file

# %%
df = pd.read_csv('grammarchecks.csv')

# %% [markdown]
# Prepare lists determining which columns should be contained in which table

# %%
languages_headers = ['language_id','lang_name', 'glottocode', 'walscode', 'iso639_3', 'lat', 
                     'lon', 'coord_notes', 'area_wals', 'area_glottolog', 'sort_affiliation', 'genus_wals', 'family_genus']
core_props_headers = ['language_id','constituent_order','constituent_order_wals','adposition_order','adposition_order_wals',
                      'genitive_order','genitive_order_wals','demonstrative_order', 'demonstrative_order_wals','definite_article','article_distinct_third',
                      'demonstrative_as_third','nominal_person','apc_direction','bound_person_direction','person_allowed',
                      'person_third_available','number_allowed','ppdc']
article_props_headers = ['language_id','article_order','demonstrative_w_article','nominal_person_w_article']

# %% [markdown]
# Check that the right (sub)dataframes are picked out

# %%
df[languages_headers]
# Out:
#      language_id          lang_name glottocode walscode iso639_3        lat  \
# 0              1           Japanese   nucl1643      jpn      jpn  35.000000
# 1              2             Korean   kore1280      kor      kor  37.500000
# 2              3             Evenki   even1259      eve      evn  61.972000
# 3              4            Turkish   nucl1301      tur      tur  39.866700
# 4              5         Mangarrayi   mang1381      myi      mpc -14.800000
# ..           ...                ...        ...      ...      ...        ...
# 129          130           Mandarin   mand1415      mnd      cmn  40.020900
# 130          131             Lakkia   lakk1238      lkk      lbc  24.116900
# 131          132          Hungarian   hung1274      hun      hun  46.906859
# 132          133            Finnish   finn1318      fin      fin  64.762800
# 133          134  Classical Nahuatl   clas1250      NaN      nci  19.720000
#
#             lon                                        coord_notes  \
# 0    135.000000                                                NaN
# 1    128.000000                                                NaN
# 2     94.689000                                                NaN
# 3     32.866700                                                NaN
# 4    133.500000  glottolog 4.1 longitude shifted, use glottolog...
# ..          ...                                                ...
# 129  116.228000                                                NaN
# 130  110.106000                                                NaN
# 131   19.655527                                                NaN
# 132   25.557700                                                NaN
# 133  -96.970000                                                NaN
#
#          area_wals area_glottolog  \
# 0          Eurasia        Eurasia
# 1          Eurasia        Eurasia
# 2          Eurasia        Eurasia
# 3          Eurasia        Eurasia
# 4        Australia      Australia
# ..             ...            ...
# 129        Eurasia        Eurasia
# 130        Eurasia        Eurasia
# 131        Eurasia        Eurasia
# 132        Eurasia        Eurasia
# 133  North America  North America
#
#                                       sort_affiliation  genus_wals  \
# 0                                    (Altaic?) Isolate    Japanese
# 1                                    (Altaic?) Isolate      Korean
# 2                                   (Altaic?) Tungusic    Tungusic
# 3                                     (Altaic?) Turkic      Turkic
# 4            (Australian) Mangarrayi-Maran, Mangarrayi  Mangarrayi
# ..                                                 ...         ...
# 129                              Sino-Tibetan, Sinitic     Chinese
# 130                    Tai-Kadai, Kam-Tai, Lakkia-Biao       Kadai
# 131                                      Uralic, Ugric       Ugric
# 132                                     Uralic, Finnic      Finnic
# 133  Uto-Aztecan, Aztecan, Nahuatl, Central Nahuatl...     Aztecan
#
#                      family_genus
# 0                         Japonic
# 1                        Koreanic
# 2                        Tungusic
# 3                          Turkic
# 4    Mangarrayi-Maran, Mangarrayi
# ..                            ...
# 129         Sino-Tibetan, Sinitic
# 130            Tai-Kadai, Kam-Tai
# 131                 Uralic, Ugric
# 132                Uralic, Finnic
# 133          Uto-Aztecan, Aztecan
#
# [134 rows x 13 columns]

# %%
df[core_props_headers]
# Out:
#      language_id constituent_order constituent_order_wals adposition_order  \
# 0              1                OV                     OV             post
# 1              2                OV                     OV             post
# 2              3                OV                     OV             post
# 3              4                OV                     OV             post
# 4              5                OV                     OV              pre
# ..           ...               ...                    ...              ...
# 129          130                VO                     VO            NoDom
# 130          131                VO                    NaN              pre
# 131          132                VO                     VO             post
# 132          133                VO                     VO             post
# 133          134                NC                    NaN          NoAdpos
#
#     adposition_order_wals genitive_order genitive_order_wals  \
# 0                    post           GenN                GenN
# 1                    post           GenN                GenN
# 2                    post           GenN                GenN
# 3                    post           GenN                GenN
# 4                     pre          NoDom               NoDom
# ..                    ...            ...                 ...
# 129                 NoDom           GenN                GenN
# 130                   NaN           GenN                 NaN
# 131                  post           GenN                GenN
# 132                  post           GenN                GenN
# 133                   NaN        unclear                 NaN
#
#     demonstrative_order demonstrative_order_wals  \
# 0                  DemN                     DemN
# 1                  DemN                     DemN
# 2                  DemN                     DemN
# 3                  DemN                     DemN
# 4                  DemN                     DemN
# ..                  ...                      ...
# 129                DemN                     DemN
# 130                NDem                      NaN
# 131                DemN                     DemN
# 132                DemN                     DemN
# 133               mixed                      NaN
#
#                     definite_article article_distinct_third  \
# 0                                  n                      n
# 1                                  n                      n
# 2                                  n                      n
# 3                                  n                      n
# 4                                  n                      n
# ..                               ...                    ...
# 129                                n                      n
# 130                                n                      n
# 131                                y                      y
# 132  n (but sm case marking effects)                      n
# 133                                n                      n
#
#     demonstrative_as_third nominal_person apc_direction  \
# 0                        n              y           pre
# 1                        n              y           pre
# 2                        n              y           pre
# 3                        y              y           pre
# 4                        y              y           pre
# ..                     ...            ...           ...
# 129                      n              y           pre
# 130                      n              y           pre
# 131                      n              y           pre
# 132                      n              y           pre
# 133                    NaN              y           NaN
#
#     bound_person_direction person_allowed person_third_available  \
# 0                        n            all                      y
# 1                        n            all                      y
# 2                        n            all                      y
# 3                        n            all                      y
# 4                        n            all                      y
# ..                     ...            ...                    ...
# 129                      n            all                      y
# 130                      n            NaN                      ?
# 131                      n           no 3                      n
# 132                      n            all                      y
# 133                    pre            all                      y
#
#     number_allowed ppdc
# 0           non-sg    y
# 1           non-sg    y
# 2              all  NaN
# 3           non-sg  NaN
# 4           non-sg  NaN
# ..             ...  ...
# 129         non-sg    y
# 130            NaN  NaN
# 131         non-sg  NaN
# 132         non-sg  NaN
# 133            all  NaN
#
# [134 rows x 19 columns]

# %% [markdown]
# Article properties are only relevant for languages with articles, so there are a lot of NA values. We are getting rid of any rows that contain three (or more) NA values (because we have three contentful columns). I'm avoiding a threshold of 1 because the columns concerning combinability of articles with demonstratives and nominal person are not established in as much detail in the current dataset.

# %%
df[article_props_headers].dropna(thresh=3)
# Out:
#      language_id article_order  \
# 19            20          NArt
# 26            27          ArtN
# 35            36          NArt
# 36            37          NArt
# 38            39          NArt
# 40            41          NArt
# 41            42          NArt
# 44            45          NArt
# 45            46          NArt
# 48            49          ArtN
# 49            50          ArtN
# 50            51          ArtN
# 54            55          ArtN
# 60            61          NArt
# 61            62          ArtN
# 62            63          ArtN
# 63            64          ArtN
# 66            67          ArtN
# 67            68          ArtN
# 69            70          ArtN
# 73            74          ArtN
# 74            75          ArtN
# 80            81          ArtN
# 83            84           NaN
# 86            87          ArtN
# 87            88          ArtN
# 88            89          ArtN
# 89            90          ArtN
# 90            91          ArtN
# 95            96          NArt
# 96            97          NArt
# 97            98          ArtN
# 98            99          ArtN
# 99           100          ArtN
# 100          101          ArtN
# 101          102          ArtN
# 102          103          ArtN
# 103          104          ArtN
# 105          106          NArt
# 106          107          NArt
# 107          108          NArt
# 111          112          NArt
# 112          113          ArtN
# 113          114          ArtN
# 123          124          ArtN
# 124          125          NArt
# 126          127          ArtN
# 131          132          ArtN
#
#                                demonstrative_w_article  \
# 19   n (demonstrative modifier), y („appositive“ de...
# 26                                                   y
# 35                                                   y
# 36                                                 NaN
# 38                                                   y
# 40    n (or y, depending on analysis of demonstrative)
# 41                        y? (no example given though)
# 44                                        y (optional)
# 45                                        y (optional)
# 48                                         y (def agr)
# 49                                         y (def agr)
# 50                                  y (def. agreement)
# 54                                                  n?
# 60                                                   y
# 61   y (Art N Deict Part, if prenominal one combine...
# 62                                                   y
# 63                                                   y
# 66                                                   y
# 67                                                   y
# 69                                        y (optional)
# 73   no distinct dem.adjectives! [Art N Adv, the wo...
# 74                                                   n
# 80                                                   y
# 83                         y (high register exception)
# 86                                                   n
# 87                                                   n
# 88                                                   n
# 89                                                 NaN
# 90                                                   y
# 95                                                   y
# 96             n (prenominal dem), y (postnominal dem)
# 97                          n (unless postnominal Dem)
# 98                          n (unless postnominal Dem)
# 99                         n (unless postnominal Dem?)
# 100                         n (unless postnominal Dem)
# 101                                                  n
# 102                                                  n
# 103                                                  n
# 105                                   n (prescriptive)
# 106                                   y (substandard?)
# 107                                   y (substandard?)
# 111                                                  n
# 112                                                  n
# 113                                                  n
# 123                                                NaN
# 124                                                  y
# 126                                                  y
# 131                                                  y
#
#     nominal_person_w_article
# 19                         y
# 26                   unclear
# 35                   unclear
# 36                         y
# 38                         y
# 40                         y
# 41                         y
# 44                         y
# 45                         y
# 48                         y
# 49                         y
# 50                         y
# 54                         n
# 60                         y
# 61                         y
# 62                         y
# 63                   unclear
# 66                         n
# 67                         y
# 69                       NaN
# 73                         n
# 74                         n
# 80                         n
# 83                         y
# 86                         n
# 87                         n
# 88                         n
# 89                         y
# 90                         y
# 95                         y
# 96                         y
# 97                         y
# 98                         y
# 99                         n
# 100                        y
# 101                        n
# 102                        n
# 103                        n
# 105                        y
# 106                      NaN
# 107                        y
# 111                        n
# 112                        y
# 113                        y
# 123                        y
# 124                        y
# 126                        y
# 131                        n

# %%
df[languages_headers].to_sql('languages', con=conn, if_exists='append',  index=False)
# Out:
# 134

# %%
df[core_props_headers].to_sql('core_properties', con=conn, if_exists='append',  index=False)
# Out:
# 134

# %%
df[article_props_headers].dropna(thresh=3).to_sql('article_properties', con=conn, if_exists='append',  index=False)
# Out:
# 48

# %% [markdown]
# # Prepare the datasources table
#
# Create a copy of the dataframe containing only the language_id and refs columns.
# Creating a copy avoids problems when dropping columns and replacing empty fields later on.

# %%
references = df[['language_id','refs']].copy()

# %% [markdown]
# Create a new column where the reference strings are split into lists of references (delimiter is the semicolon). Then drop the original refs column as it's no longer needed.

# %%
references['splitrefs'] = references['refs'].str.split(';')
references.drop(columns='refs',inplace=True)

# %% [markdown]
# Ensure that fields containing no reference list (i.e. because there was no reference and there is NULL/na value instead) get replaced by an empty list to ensure proper behaviour later on.

# %%
references.loc[:,'splitrefs'] = references['splitrefs'].apply(lambda x: x if isinstance(x, list) else [])
print(references)
# Out:
#      language_id                                          splitrefs
# 0              1  [Hinds 1988:254, 261,  Noguchi 1997:780,  Furu...
# 1              2          [Sohn 1994:284, 292,  Choi 2014: 151-154]
# 2              3                          [Nedjalkov 1997:197, 199]
# 3              4                         [Kornfilt 1997:288, 297f.]
# 4              5                     [Merlan 1989 [1982]: 103, 203]
# ..           ...                                                ...
# 129          130                   [Boskovic & Hsieh 2013:sec. 7.3]
# 130          131                                     [Fan 2019:137]
# 131          132  [Kenesei,Vago & Fenyvesi 1998:269,  Höhn 2016:...
# 132          133                   [Sulkala & Karjalainen 1992:277]
# 133          134     [Andrews 1975:192-194,  Andrews 2003:ch. 17.3]
#
# [134 rows x 2 columns]

# %% [markdown]
# Explode the splitrefs field

# %%
ref_exploded = references.explode('splitrefs').reset_index(drop=True)
print(ref_exploded)
# Out:
#      language_id                         splitrefs
# 0              1               Hinds 1988:254, 261
# 1              1                  Noguchi 1997:780
# 2              1              Furuya 2008:sec. 3.2
# 3              1                      Inokuma 2009
# 4              1                    (Coulmas 1982)
# ..           ...                               ...
# 167          132  Kenesei,Vago & Fenyvesi 1998:269
# 168          132                     Höhn 2016:559
# 169          133    Sulkala & Karjalainen 1992:277
# 170          134              Andrews 1975:192-194
# 171          134             Andrews 2003:ch. 17.3
#
# [172 rows x 2 columns]

# %%
ref_exploded['ref_short'] = ref_exploded['splitrefs'].str.split(':').str[0].str.lstrip()
ref_exploded['ref_pages'] = ref_exploded['splitrefs'].str.split(':').str[1].str.lstrip()

# %% [markdown]
# Drop unnecessary splitrefs column and check output

# %%
ref_exploded.drop(columns='splitrefs', inplace=True)
print(ref_exploded)
# Out:
#      language_id                     ref_short ref_pages
# 0              1                    Hinds 1988  254, 261
# 1              1                  Noguchi 1997       780
# 2              1                   Furuya 2008  sec. 3.2
# 3              1                  Inokuma 2009       NaN
# 4              1                (Coulmas 1982)       NaN
# ..           ...                           ...       ...
# 167          132  Kenesei,Vago & Fenyvesi 1998       269
# 168          132                     Höhn 2016       559
# 169          133    Sulkala & Karjalainen 1992       277
# 170          134                  Andrews 1975   192-194
# 171          134                  Andrews 2003  ch. 17.3
#
# [172 rows x 3 columns]

# %% [markdown]
# Enter dataframe into SQL table

# %%
ref_exploded.to_sql('datasources', con=conn, if_exists='replace',  index=False)
# Out:
# 172

# %% [markdown]
# Since we used "if_exists='replace'" a previously defined FOREIGN KEY relation does not persist and we need to (re-)establish it with the following commands, which first create a cursor and use that to execute an SQL command to add the FOREIGN KEY constraint to link the datasources table to the languages table.

# %%
conn = psycopg2.connect(conn_string 
                        ) 
conn.autocommit = True
cursor = conn.cursor() 

cursor.execute('ALTER TABLE public.datasources ADD CONSTRAINT datasources_languages_fk FOREIGN KEY (language_id) REFERENCES public.languages(language_id) ON DELETE CASCADE;')

# %% [markdown]
# Close connection to database

# %%
conn.close()
